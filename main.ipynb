# %%
import langchain

# %%
from langchain import agents, chat_models, tools

# %%
model = tools.
# Out:
#   Cell In[6], line 1
#     model = tools.
#                   ^
# SyntaxError: invalid syntax

# %%
import os
from dotenv import load_dotenv

has_anything_loaded = load_dotenv()

if not has_anything_loaded:
    raise ValueError("No .env file found")

OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")

# %%
agent = agents.create_agent("gpt-5-nano")

# %%
# from langchain import messages
from langchain.messages import SystemMessage, HumanMessage

response = agent.invoke(
    {
        "messages": [
            SystemMessage(
                content="You are a helpful assistant that can answer questions about the weather."
            ),
            HumanMessage(content="What is the weather in Istanbul?"),
        ]
    }
)

# %%
response
# Out:
# {'messages': [SystemMessage(content='You are a helpful assistant that can answer questions about the weather.', additional_kwargs={}, response_metadata={}, id='f007f757-4087-4035-91d6-2a3a46ff58a0'),
#   HumanMessage(content='What is the weather in Istanbul?', additional_kwargs={}, response_metadata={}, id='36df0155-f6ee-445c-b71e-ff0e33e572a1'),
# ...

# %%
response['messages'][2].content
# Out:
# 'I can help with that. Do you want the current conditions right now or a forecast for Istanbul? And would you prefer Celsius or Fahrenheit? If you’d like, I can fetch the latest live conditions for Istanbul.'
